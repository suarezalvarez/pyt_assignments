# %% [markdown]
# ### Dictionary of subsequences

# %%
number_of_repetitions = 1

subsequences = {}

with open('../../data_assignment_3/sequence_fragments.txt' , 'r') as subsequences_filename:
    for subsequence in subsequences_filename:
         
        subsequences[subsequence.strip()] = 0


number_of_repetitions
# Out:
# 1

# %% [markdown]
# ## Loop

# %%
with open('../../data_assignment_3/example_fasta_file.fa' , 'r') as fasta_filename:
              
    protein_counter = 0             # initialize counter
    seq = ""                        # define seq

    for line in fasta_filename:                       # iterate over lines in fasta

                        
        if line.startswith(">") and seq:            
            
            
            protein_counter += 1

            for subsequence in subsequences: 
                
                if seq.count(subsequence.strip()) >= number_of_repetitions:                    
                    subsequences[subsequence.strip()] += 1
                    
            
            
            seq = ""




        elif not line.startswith(">"):
            
            seq += line.strip()




    protein_counter += 1

    for subsequence in subsequences:                
        if seq.count(subsequence.strip()) >= number_of_repetitions:                    
            subsequences[subsequence.strip()] += 1
# Out:
# {'AAVP': 2, 'AC': 33, 'ACV': 4, 'AEAV': 4, 'AF': 41, 'AFV': 5, 'AINP': 2, 'ALSV': 1, 'CGTG': 0, 'CITP': 0, 'CT': 33, 'CTD': 1, 'CVDW': 0, 'DA': 46, 'DAC': 5, 'DF': 49, 'DFY': 6, 'DG': 42, 'DGI': 8, 'DKED': 0, 'DKPD': 3, 'DKTI': 0, 'DP': 45, 'DPS': 11, 'DRYF': 0, 'DS': 47, 'DSN': 10, 'DSSD': 3, 'DTDC': 0, 'EDPT': 4, 'EEYY': 0, 'EG': 46, 'EGV': 13, 'EIEL': 2, 'EL': 51, 'ELI': 12, 'EMMI': 0, 'EPSE': 4, 'ETAQ': 0, 'EY': 42, 'EYD': 3, 'FALL': 0, 'FEPK': 0, 'FG': 51, 'FGK': 12, 'FI': 38, 'FIS': 10, 'FQ': 41, 'FQD': 14, 'FQRE': 0, 'FQS': 11, 'FR': 35, 'FRI': 4, 'FVAG': 2, 'FVNE': 0, 'GA': 50, 'GAL': 14, 'GAT': 15, 'GEAC': 1, 'GGSD': 3, 'GI': 43, 'GIK': 9, 'GP': 42, 'GPV': 9, 'GS': 48, 'GSN': 8, 'GT': 49, 'GTI': 7, 'GTQ': 7, 'HKTA': 0, 'HL': 46, 'HLR': 8, 'HSGV': 0, 'IF': 36, 'IFN': 5, 'IGAT': 0, 'IKPL': 2, 'IL': 50, 'ILL': 24, 'IP': 42, 'IPE': 19, 'IPIV': 0, 'IQEM': 1, 'IQLR': 0, 'IS': 49, 'ISGP': 0, 'ISK': 12, 'IV': 48, 'IVL': 14, 'IVMD': 1, 'KAVE': 2, 'KAYN': 3, 'KD': 45, 'KDE': 16, 'KF': 39, 'KFR': 9, 'KFS': 9, 'KIYT': 0, 'KM': 35, 'KML': 20, 'KN': 45, 'KNIT': 1, 'KNT': 5, 'KR': 49, 'KRE': 9, 'KT': 47, 'KTE': 10, 'KTLY': 3, 'KVYD': 2, 'KYDT': 0, 'LA': 48, 'LAA': 33, 'LFCV': 0, 'LHKR': 2, 'LIVG': 1, 'LNEV': 2, 'LP': 49, 'LPK': 7, 'LSED': 3, 'LT': 48, 'LTD': 10, 'LTHL': 3, 'LV': 50, 'LVE': 28, 'LVKD': 3, 'LY': 44, 'LYD': 15, 'LYER': 0, 'LYP': 8, 'MD': 40, 'MDK': 6, 'MQRL': 0, 'MT': 33, 'MTS': 3, 'MV': 35, 'MVS': 6, 'MYFL': 0, 'NA': 33, 'NAH': 2, 'ND': 34, 'NDK': 2, 'NEWY': 0, 'NKPF': 0, 'NRAS': 0, 'NT': 37, 'NTA': 9, 'NTAP': 3, 'NTVS': 1, 'PC': 30, 'PCC': 0, 'PE': 50, 'PEH': 7, 'PEK': 9, 'PKLY': 0, 'PLLG': 1, 'PLPE': 3, 'PQPK': 2, 'PT': 48, 'PTW': 0, 'PWVQ': 0, 'QI': 46, 'QIK': 13, 'QK': 41, 'QKN': 3, 'QNLA': 2, 'QV': 44, 'QVA': 13, 'RD': 50, 'RDA': 9, 'RE': 50, 'REL': 22, 'RET': 11, 'RG': 49, 'RGA': 18, 'RL': 50, 'RLD': 8, 'RLL': 21, 'RR': 41, 'RRI': 13, 'RS': 45, 'RSW': 3, 'SAED': 3, 'SEEG': 3, 'SPYD': 0, 'SRGA': 0, 'ST': 48, 'STT': 3, 'SV': 50, 'SVR': 17, 'SVTM': 1, 'SW': 33, 'SWY': 5, 'SYCE': 0, 'TI': 39, 'TIC': 4, 'TL': 49, 'TLE': 16, 'TLRP': 3, 'TLV': 17, 'TQVC': 1, 'TT': 41, 'TTCT': 3, 'TTY': 7, 'TVLI': 2, 'VA': 48, 'VAI': 17, 'VATA': 2, 'VDKD': 0, 'VG': 44, 'VGAP': 1, 'VGR': 8, 'VK': 50, 'VKY': 4, 'VL': 51, 'VLI': 12, 'VM': 38, 'VMV': 6, 'VP': 42, 'VPV': 11, 'VQ': 42, 'VQL': 14, 'VRIC': 0, 'VRLE': 0, 'VS': 48, 'VSF': 7, 'VTLI': 2, 'WK': 31, 'WKF': 1, 'WNPA': 0, 'WTQK': 0, 'WV': 19, 'WVE': 2, 'YAYG': 0, 'YCMR': 0, 'YETR': 0, 'YL': 48, 'YLD': 9, 'YQ': 34, 'YQK': 2, 'YS': 40, 'YSS': 7}

# %% [markdown]
# ### Function

# %%
def calculate_aminoacid_frequencies(fasta_filename, 
                                    subsequences_filename, 
                                    number_of_repetitions, 
                                    output_filename):
    
    '''Given a multi-line FASTA file (fasta_filename) and a "sub-sequences" file (subsequences_filename)
    (one sequence in each line), calculates the proportion of proteins in the FASTA file containing at least N times (number_of repetitions)
    each of the sub-sequences. Output is a tabular file sorted by proportion in descending order.'''



    ### create dictionary of subsequences ###

    subsequences = {} # empty dictionary to be filled with subsequences

    with open(subsequences_filename , 'r') as subsequences_filename:
        
        
        for subsequence in subsequences_filename:
         
            subsequences[subsequence.strip()] = 0    # add subsequences as keys





    ### count subsequences in each sequence ###

    with open(fasta_filename , 'r') as fasta_filename:
              
        protein_counter = 0             # initialize counter
        seq = ""                        # define seq



        for line in fasta_filename:                       # iterate over lines in fasta


            if line.startswith(">") and seq:            
                protein_counter += 1

                for subsequence in subsequences: 

                    if seq.count(subsequence.strip()) >= number_of_repetitions:                    
                        subsequences[subsequence.strip()] += 1

                seq = ""




            elif not line.startswith(">"):

                seq += line.strip()



        # take into account last protein
                
        protein_counter += 1

        for subsequence in subsequences:                
            if seq.count(subsequence.strip()) >= number_of_repetitions:                    
                subsequences[subsequence.strip()] += 1



    return(subsequences)



calculate_aminoacid_frequencies('../../data_assignment_3/example_fasta_file.fa' ,
                                '../../data_assignment_3/sequence_fragments.txt',
                                number_of_repetitions=1,
                                output_filename='../../data_assignment_3/empty'
                                )
# Out:
# {'AAVP': 2,
#  'AC': 33,
#  'ACV': 4,
#  'AEAV': 4,
#  'AF': 41,
#  'AFV': 5,
#  'AINP': 2,
#  'ALSV': 1,
#  'CGTG': 0,
#  'CITP': 0,
#  'CT': 33,
#  'CTD': 1,
#  'CVDW': 0,
#  'DA': 46,
#  'DAC': 5,
#  'DF': 49,
#  'DFY': 6,
#  'DG': 42,
#  'DGI': 8,
#  'DKED': 0,
#  'DKPD': 3,
#  'DKTI': 0,
#  'DP': 45,
#  'DPS': 11,
#  'DRYF': 0,
#  'DS': 47,
#  'DSN': 10,
#  'DSSD': 3,
#  'DTDC': 0,
#  'EDPT': 4,
#  'EEYY': 0,
#  'EG': 46,
#  'EGV': 13,
#  'EIEL': 2,
#  'EL': 51,
#  'ELI': 12,
#  'EMMI': 0,
#  'EPSE': 4,
#  'ETAQ': 0,
#  'EY': 42,
#  'EYD': 3,
#  'FALL': 0,
#  'FEPK': 0,
#  'FG': 51,
#  'FGK': 12,
#  'FI': 38,
#  'FIS': 10,
#  'FQ': 41,
#  'FQD': 14,
#  'FQRE': 0,
#  'FQS': 11,
#  'FR': 35,
#  'FRI': 4,
#  'FVAG': 2,
#  'FVNE': 0,
#  'GA': 50,
#  'GAL': 14,
#  'GAT': 15,
#  'GEAC': 1,
#  'GGSD': 3,
#  'GI': 43,
#  'GIK': 9,
#  'GP': 42,
#  'GPV': 9,
#  'GS': 48,
#  'GSN': 8,
#  'GT': 49,
#  'GTI': 7,
#  'GTQ': 7,
#  'HKTA': 0,
#  'HL': 46,
#  'HLR': 8,
#  'HSGV': 0,
#  'IF': 36,
#  'IFN': 5,
#  'IGAT': 0,
#  'IKPL': 2,
#  'IL': 50,
#  'ILL': 24,
#  'IP': 42,
#  'IPE': 19,
#  'IPIV': 0,
#  'IQEM': 1,
#  'IQLR': 0,
#  'IS': 49,
#  'ISGP': 0,
#  'ISK': 12,
#  'IV': 48,
#  'IVL': 14,
#  'IVMD': 1,
#  'KAVE': 2,
#  'KAYN': 3,
#  'KD': 45,
#  'KDE': 16,
#  'KF': 39,
#  'KFR': 9,
#  'KFS': 9,
#  'KIYT': 0,
#  'KM': 35,
#  'KML': 20,
#  'KN': 45,
#  'KNIT': 1,
#  'KNT': 5,
#  'KR': 49,
#  'KRE': 9,
#  'KT': 47,
#  'KTE': 10,
#  'KTLY': 3,
#  'KVYD': 2,
#  'KYDT': 0,
#  'LA': 48,
#  'LAA': 33,
#  'LFCV': 0,
#  'LHKR': 2,
#  'LIVG': 1,
#  'LNEV': 2,
#  'LP': 49,
#  'LPK': 7,
#  'LSED': 3,
#  'LT': 48,
#  'LTD': 10,
#  'LTHL': 3,
#  'LV': 50,
#  'LVE': 28,
#  'LVKD': 3,
#  'LY': 44,
#  'LYD': 15,
#  'LYER': 0,
#  'LYP': 8,
#  'MD': 40,
#  'MDK': 6,
#  'MQRL': 0,
#  'MT': 33,
#  'MTS': 3,
#  'MV': 35,
#  'MVS': 6,
#  'MYFL': 0,
#  'NA': 33,
#  'NAH': 2,
#  'ND': 34,
#  'NDK': 2,
#  'NEWY': 0,
#  'NKPF': 0,
#  'NRAS': 0,
#  'NT': 37,
#  'NTA': 9,
#  'NTAP': 3,
#  'NTVS': 1,
#  'PC': 30,
#  'PCC': 0,
#  'PE': 50,
#  'PEH': 7,
#  'PEK': 9,
#  'PKLY': 0,
#  'PLLG': 1,
#  'PLPE': 3,
#  'PQPK': 2,
#  'PT': 48,
#  'PTW': 0,
#  'PWVQ': 0,
#  'QI': 46,
#  'QIK': 13,
#  'QK': 41,
#  'QKN': 3,
#  'QNLA': 2,
#  'QV': 44,
#  'QVA': 13,
#  'RD': 50,
#  'RDA': 9,
#  'RE': 50,
#  'REL': 22,
#  'RET': 11,
#  'RG': 49,
#  'RGA': 18,
#  'RL': 50,
#  'RLD': 8,
#  'RLL': 21,
#  'RR': 41,
#  'RRI': 13,
#  'RS': 45,
#  'RSW': 3,
#  'SAED': 3,
#  'SEEG': 3,
#  'SPYD': 0,
#  'SRGA': 0,
#  'ST': 48,
#  'STT': 3,
#  'SV': 50,
#  'SVR': 17,
#  'SVTM': 1,
#  'SW': 33,
#  'SWY': 5,
#  'SYCE': 0,
#  'TI': 39,
#  'TIC': 4,
#  'TL': 49,
#  'TLE': 16,
#  'TLRP': 3,
#  'TLV': 17,
#  'TQVC': 1,
#  'TT': 41,
#  'TTCT': 3,
#  'TTY': 7,
#  'TVLI': 2,
#  'VA': 48,
#  'VAI': 17,
#  'VATA': 2,
#  'VDKD': 0,
#  'VG': 44,
#  'VGAP': 1,
#  'VGR': 8,
#  'VK': 50,
#  'VKY': 4,
#  'VL': 51,
#  'VLI': 12,
#  'VM': 38,
#  'VMV': 6,
#  'VP': 42,
#  'VPV': 11,
#  'VQ': 42,
#  'VQL': 14,
#  'VRIC': 0,
#  'VRLE': 0,
#  'VS': 48,
#  'VSF': 7,
#  'VTLI': 2,
#  'WK': 31,
#  'WKF': 1,
#  'WNPA': 0,
#  'WTQK': 0,
#  'WV': 19,
#  'WVE': 2,
#  'YAYG': 0,
#  'YCMR': 0,
#  'YETR': 0,
#  'YL': 48,
#  'YLD': 9,
#  'YQ': 34,
#  'YQK': 2,
#  'YS': 40,
#  'YSS': 7}
